# %%
load_ext run_and_test

# %% [markdown]
# # Exercise 1

# %% [markdown]
# ## Templates

# %%
# %pycat exercise_6_1_template.py
# Out:
# # L is a list of lists of integers
# #
# # Returns a pair (F, R) where F is the sorted list of all
# # integers in L, and R is a list of lists obtained by
# # partitioning F into sublists whose lengths match those
# # of the corresponding sublists in L.
# #
# # The argument L must not be modified by the function.
#
# def f1(L):
#     return [], []
#     # REPLACE THE RETURN STATEMENT ABOVE WITH YOUR CODE

# %% [markdown]
# ## Tests

# %%
# %%run_and_test python3 -c "from exercise_6_1 import f1; print(f1([[]]))"
#
# '([], [[]])\n'

# %%
# %%run_and_test python3 -c "from exercise_6_1 import f1; print(f1([[1]]))"
#
# '([1], [[1]])\n'

# %%
# %%run_and_test python3 -c "from exercise_6_1 import f1; print(f1([[2], [1]]))"
#
# '([1, 2], [[1], [2]])\n'

# %%
# %%run_and_test python3 -c "from exercise_6_1 import f1; print(f1([[3, 1], [2]]))"
#
# '([1, 2, 3], [[1, 2], [3]])\n'

# %%
# %%run_and_test python3 -c "from exercise_6_1 import f1; print(f1([[2], [3, 1]]))"
#
# '([1, 2, 3], [[1], [2, 3]])\n'

# %%
statements = 'from exercise_6_1 import f1; '\
            'L = [[4, 8], [6, 3, 0], [7]]; print(f1(L))'

# %%
# %%run_and_test python3 -c "$statements"
#
# '([0, 3, 4, 6, 7, 8], [[0, 3], [4, 6, 7], [8]])\n'

# %%
statements = 'from exercise_6_1 import f1; '\
            'L = [[-4, -15], [5, -11, -4], [-12, -5, -16, 3], [1, 8, -8, 3, -17]]; '\
            'print(f1(L))'

# %%
# %%run_and_test python3 -c "$statements"
#
# '([-17, -16, -15, -12, -11, -8, -5, -4, -4, 1, 3, 3, 5, 8],'
# ' [[-17, -16], [-15, -12, -11], [-8, -5, -4, -4], [1, 3, 3, 5, 8]])\n'

# %%
statements = 'from exercise_6_1 import f1; '\
            'L = [[4, 10, -19, 11, 15], [6, -7, 16, 9], [6, 12, 12], '\
            '     [-19, -8, 6, 18, 12]]; print(f1(L))'

# %%
# %%run_and_test python3 -c "$statements"
#
# '([-19, -19, -8, -7, 4, 6, 6, 6, 9, 10, 11, 12, 12, 12, 15, 16, 18],'
# ' [[-19, -19, -8, -7, 4], [6, 6, 6, 9], [10, 11, 12], [12, 12, 15, 16, 18]])\n'

# %%
statements = 'from exercise_6_1 import f1; '\
             'L = [[5], [54, -48, 71, -67, 31, -61], [2, -95, 86, 84, -86, -50], '\
             '     [38, 57, 54, 41, -58, -63, -79], [95, -66, 43, 50, 87, 16, -37], '\
             '     [48, -99, -64]]; print(f1(L))'

# %%
# %%run_and_test python3 -c "$statements"
#
# '([-99, -95, -86, -79, -67, -66, -64, -63, -61, -58, -50, -48, -37, '
#    '2, 5, 16, 31, 38, 41, 43, 48, 50, 54, 54, 57, 71, 84, 86, 87, 95], '
#  '[[-99], [-95, -86, -79, -67, -66, -64], [-63, -61, -58, -50, -48, -37], '
#   '[2, 5, 16, 31, 38, 41, 43], [48, 50, 54, 54, 57, 71, 84], '
#   '[86, 87, 95]])\n'

# %% [markdown]
# # Exercise 2

# %% [markdown]
# ## Templates

# %%
# %pycat exercise_6_2_template.py
# Out:
# # L is a nonempty list of lists of integers forming a square,
# # i and j are integers between 1 and the size of the square,
# # and major is a Boolean.
# #
# # Returns the sum of the elements on the diagonal passing
# # through position (i, j): the major diagonal (NW-SE direction)
# # if major is True, and the minor diagonal (SW-NE direction)
# # otherwise.
# #
# # Illustration for a square of size 5:
# #           j
# #       1 2 3 4 5
# #    1  . . . . .
# #    2  . . . . .
# #  i 3  . . . . .
# #    4  . . . . .
# #    5  . . . . .
#
# def f2(L, i, j, major=True):
#     return 0
#     # REPLACE THE RETURN STATEMENT ABOVE WITH YOUR CODE

# %% [markdown]
# ## Tests

# %%
statements = 'from exercise_6_2 import f2; '\
             'print(f2([[1]], 1, 1)); print(f2([[1]], 1, 1, False))'

# %%
# %%run_and_test python3 -c "$statements"
# '1\n1\n'

# %%
statements = 'from itertools import product; '\
             'from exercise_6_2 import f2; '\
             'L = [[1, 2], [3, 4]]; '\
             'print({(i, j): f2(L, i, j) '\
             '          for (i, j) in product(range(1, 3), repeat=2)})'

# %%
# %%run_and_test python3 -c "$statements"
#
# '{(1, 1): 5, (1, 2): 2, (2, 1): 3, (2, 2): 5}\n'

# %%
statements = 'from itertools import product; '\
             'from exercise_6_2 import f2; '\
             'L = [[1, 2], [3, 4]]; '\
             'print({(i, j): f2(L, i, j, False) '\
             '          for (i, j) in product(range(1, 3), repeat=2)})'

# %%
# %%run_and_test python3 -c "$statements"
#
# '{(1, 1): 1, (1, 2): 5, (2, 1): 5, (2, 2): 4}\n'

# %%
statements = 'from itertools import product; '\
             'from exercise_6_2 import f2; '\
             'L = [[1, 7, 9], [0, 4, 8], [6, 4, 2]]; '\
             'print({(i, j): f2(L, i, j) '\
             '          for (i, j) in product(range(1, 4), repeat=2)})'

# %%
# %%run_and_test python3 -c "$statements"
#
# '{(1, 1): 7, (1, 2): 15, (1, 3): 9, (2, 1): 4, (2, 2): 7,'
# ' (2, 3): 15, (3, 1): 6, (3, 2): 4, (3, 3): 7}\n'

# %%
statements = 'from itertools import product; '\
             'from exercise_6_2 import f2; '\
             'L = [[1, 7, 9], [0, 4, 8], [6, 4, 2]]; '\
             'print({(i, j): f2(L, i, j, False) '\
             '          for (i, j) in product(range(1, 4), repeat=2)})'

# %%
# %%run_and_test python3 -c "$statements"
#
# '{(1, 1): 1, (1, 2): 7, (1, 3): 19, (2, 1): 7, (2, 2): 19,'
# ' (2, 3): 12, (3, 1): 19, (3, 2): 12, (3, 3): 2}\n'

# %%
statements = 'from itertools import product; '\
             'from exercise_6_2 import f2; '\
             'L = [[-18, -4, -16, 18], [18, -7, -5, -6], [-19, -16, -1, 2], [-16, -4, 6, -4]]; '\
             'print({(i, j): f2(L, i, j) '\
             '          for (i, j) in product(range(1, 5), repeat=2)})'

# %%
# %%run_and_test python3 -c "$statements"
#
# '{(1, 1): -30, (1, 2): -7, (1, 3): -22, (1, 4): 18, (2, 1): 8, (2, 2): -30,'
# ' (2, 3): -7, (2, 4): -22, (3, 1): -23, (3, 2): 8, (3, 3): -30, (3, 4): -7,'
# ' (4, 1): -16, (4, 2): -23, (4, 3): 8, (4, 4): -30}\n'

# %%
statements = 'from itertools import product; '\
             'from exercise_6_2 import f2; '\
             'L = [[-18, -4, -16, 18], [18, -7, -5, -6], [-19, -16, -1, 2], [-16, -4, 6, -4]]; '\
             'print({(i, j): f2(L, i, j, False) '\
             '          for (i, j) in product(range(1, 5), repeat=2)})'

# %%
# %%run_and_test python3 -c "$statements"
#
# '{(1, 1): -18, (1, 2): 14, (1, 3): -42, (1, 4): -19, (2, 1): 14, (2, 2): -42,'
# ' (2, 3): -19, (2, 4): -11, (3, 1): -42, (3, 2): -19, (3, 3): -11, (3, 4): 8,'
# ' (4, 1): -19, (4, 2): -11, (4, 3): 8, (4, 4): -4}\n'

# %%
statements = 'from itertools import product; '\
             'from exercise_6_2 import f2; '\
             'L = [[-49, -47, -50, 44, -21], [-20, 30, 44, 2, -14], [-30, -13, -6, -12, -5], '\
             '     [-39, 3, 35, -21, 19], [-2, 10, -39, -23, 28]]; '\
             'print({(i, j): f2(L, i, j) '\
             '          for (i, j) in product(range(1, 6), repeat=2)})'

# %%
# %%run_and_test python3 -c "$statements"
#
# '{(1, 1): -18, (1, 2): 4, (1, 3): -53, (1, 4): 30, (1, 5): -21, (2, 1): -21,'
# ' (2, 2): -18, (2, 3): 4, (2, 4): -53, (2, 5): 30, (3, 1): -66, (3, 2): -21,'
# ' (3, 3): -18, (3, 4): 4, (3, 5): -53, (4, 1): -29, (4, 2): -66, (4, 3): -21,'
# ' (4, 4): -18, (4, 5): 4, (5, 1): -2, (5, 2): -29, (5, 3): -66, (5, 4): -21, (5, 5): -18}\n'

# %%
statements = 'from itertools import product; '\
             'from exercise_6_2 import f2; '\
             'L = [[-49, -47, -50, 44, -21], [-20, 30, 44, 2, -14], [-30, -13, -6, -12, -5], '\
             '     [-39, 3, 35, -21, 19], [-2, 10, -39, -23, 28]]; '\
             'print({(i, j): f2(L, i, j, False) '\
             '          for (i, j) in product(range(1, 6), repeat=2)})'

# %%
# %%run_and_test python3 -c "$statements"
#
# '{(1, 1): -49, (1, 2): -67, (1, 3): -50, (1, 4): 36, (1, 5): -24, (2, 1): -67,'
# ' (2, 2): -50, (2, 3): 36, (2, 4): -24, (2, 5): 19, (3, 1): -50, (3, 2): 36,'
# ' (3, 3): -24, (3, 4): 19, (3, 5): -65, (4, 1): 36, (4, 2): -24, (4, 3): 19,'
# ' (4, 4): -65, (4, 5): -4, (5, 1): -24, (5, 2): 19, (5, 3): -65, (5, 4): -4, (5, 5): 28}\n'

# %% [markdown]
# # Exercise 3

# %% [markdown]
# ## Templates

# %%
# %pycat exercise_6_3_template.py
# Out:
# # L is a list of lists of integers forming a square
# # with even side length, and half is one of
# # 'top', 'bottom', 'left' or 'right'.
# #
# # Returns a new list of lists obtained from L by possibly
# # swapping diagonally opposite elements so that, for each
# # such pair, the element in the specified half of the square
# # is at least equal to the other one.
# #
# # For instance, ! and ? are diagonally oppposite in:
# #
# # ! . . .
# # . . . .
# # . . . .
# # . . . ?
# #
# # The integer at location ! should be at least equal to
# # the integer at location ? iff half is 'top' or 'left';
# # otherwise, they should be swapped.
# #
# # For another example, ! and ? are diagonally oppposite in:
# #
# # . . . .
# # . . ! .
# # . ? . .
# # . . . .
# #
# # The integer at location ! should be at least equal to
# # the integer at location ? iff half is 'top' or 'right';
# # otherwise, they should be swapped.
# #
# # The argument L must not be modified by the function.
#
# ...

# %% [markdown]
# ## Tests

# %%
statements = 'from exercise_6_3 import f3; '\
             'L = [[]]; '\
             'print("\n".join("".join(str(e) for e in row) for row in f3(L)))'

# %%
# %%run_and_test python3 -c "$statements"
#
# '\n'

# %%
statements = 'from exercise_6_3 import f3; '\
             'L = [[1, 2], [3, 4]]; '\
             'print("\n".join(" ".join(str(e) for e in row) for row in f3(L))); '\
             'print(); '\
             'print("\n".join(" ".join(str(e) for e in row) for row in f3(L, "bottom"))); '\
             'print(); '\
             'print("\n".join(" ".join(str(e) for e in row) for row in f3(L, "left"))); '\
             'print(); '\
             'print("\n".join(" ".join(str(e) for e in row) for row in f3(L, "right")))'

# %%
# %%run_and_test python3 -c "$statements"
#
# '''
# 4 3\n
# 2 1\n
# \n
# 1 2\n
# 3 4\n
# \n
# 4 2\n
# 3 1\n
# \n
# 1 3\n
# 2 4\n
# '''

# %%
statements = 'from exercise_6_3 import f3; '\
             'L = [[-18, -4, -16, 18], [18, -7, -5, -6], [-19, -16, -1, 2], [-16, -4, 6, -4]]; '\
             'print("\n".join(" ".join(f"{str(e):>3}" for e in row) for row in f3(L))); '\
             'print(); '\
             'print("\n".join(" ".join(f"{str(e):>3}" for e in row) for row in f3(L, "bottom"))); '\
             'print(); '\
             'print("\n".join(" ".join(f"{str(e):>3}" for e in row) for row in f3(L, "left"))); '\
             'print(); '\
             'print("\n".join(" ".join(f"{str(e):>3}" for e in row) for row in f3(L, "right")))'

# %%
# %%run_and_test python3 -c "$statements"
#
# '''
#  -4   6  -4  18\n
#  18  -1  -5  -6\n
# -19 -16  -7   2\n
# -16 -16  -4 -18\n
# \n
# -18  -4 -16 -16\n
#   2  -7 -16 -19\n
#  -6  -5  -1  18\n
#  18  -4   6  -4\n
# \n
#  -4   6 -16 -16\n
#  18  -1 -16 -19\n
#  -6  -5  -7   2\n
#  18  -4  -4 -18\n
# \n
# -18  -4  -4  18\n
#   2  -7  -5  -6\n
# -19 -16  -1  18\n
# -16 -16   6  -4\n
# '''

# %%
statements = 'from exercise_6_3 import f3; '\
             'L = [[24, 17, 35, -37, -43, -34], [-9, -25, -43, -24, 11, 2], [-1, -13, -32, -13, -5, -46], '\
                  '[28, 41, 23, 1, 13, -8], [-13, 11, 13, 20, -2, 22], [13, -30, -47, 12, -30, 7]]; '\
             'print("\n".join(" ".join(f"{str(e):>3}" for e in row) for row in f3(L))); '\
             'print(); '\
             'print("\n".join(" ".join(f"{str(e):>3}" for e in row) for row in f3(L, "bottom"))); '\
             'print(); '\
             'print("\n".join(" ".join(f"{str(e):>3}" for e in row) for row in f3(L, "left"))); '\
             'print(); '\
             'print("\n".join(" ".join(f"{str(e):>3}" for e in row) for row in f3(L, "right")))'

# %%
# %%run_and_test python3 -c "$statements"
#
# '''
#  24  17  35 -37 -30  13\n
#  22  -2  20  13  11   2\n
#  -1  13   1  23  41  28\n
# -46  -5 -13 -32 -13  -8\n
# -13  11 -24 -43 -25  -9\n
# -34 -43 -47  12 -30   7\n
# \n
#   7 -30  12 -47 -43 -34\n
#  -9 -25 -43 -24  11 -13\n
#  -8 -13 -32 -13  -5 -46\n
#  28  41  23   1  13  -1\n
#   2  11  13  20  -2  22\n
#  13 -30 -37  35  17  24\n
# \n
#  24  17  35 -47 -43 -34\n
#  22  -2  20 -24  11 -13\n
#  -1  13   1 -13  -5 -46\n
#  28  41  23 -32 -13  -8\n
#   2  11  13 -43 -25  -9\n
#  13 -30 -37  12 -30   7\n
# \n
#   7 -30  12 -37 -30  13\n
#  -9 -25 -43  13  11   2\n
#  -8 -13 -32  23  41  28\n
# -46  -5 -13   1  13  -1\n
# -13  11 -24  20  -2  22\n
# -34 -43 -47  35  17  24\n
# '''

# %%
statements = 'from exercise_6_3 import f3; '\
             'L = [[-6, 1, -70, 89, -80, 31, 10, 98], [-25, 56, 2, 48, 78, 59, 86, -53], '\
             '     [71, -84, -10, 0, 10, -4, 2, -70], [79, -55, 34, -98, -85, 14, -71, -53], '\
             '     [-98, -34, 99, 14, 74, -96, -4, 91], [-83, -36, 24, -98, 49, -31, -75, 95], '\
             '     [-41, 94, -16, 89, -35, -55, 10, 27], [80, 33, 62, -23, -58, 78, 59, -65]]; '\
             'print("\n".join(" ".join(f"{str(e):>3}" for e in row) for row in f3(L))); '\
             'print(); '\
             'print("\n".join(" ".join(f"{str(e):>3}" for e in row) for row in f3(L, "bottom"))); '\
             'print(); '\
             'print("\n".join(" ".join(f"{str(e):>3}" for e in row) for row in f3(L, "left"))); '\
             'print(); '\
             'print("\n".join(" ".join(f"{str(e):>3}" for e in row) for row in f3(L, "right")))'

# %%
# %%run_and_test -s 2000 python3 -c "$statements"
#
# '''
#  -6  59  78  89 -23  62  33  98\n
#  27  56   2  48  89  59  94 -41\n
#  95 -75 -10  49  10  24   2 -70\n
#  91  -4  34  74  14  99 -34 -53\n
# -98 -71  14 -85 -98 -96 -55  79\n
# -83 -36  -4 -98   0 -31 -84  71\n
# -53  86 -16  78 -35 -55  10 -25\n
#  80  10  31 -80 -58 -70   1 -65\n
# \n
# -65   1 -70 -58 -80  31  10  80\n
# -25  10 -55 -35  78 -16  86 -53\n
#  71 -84 -31   0 -98  -4 -36 -83\n
#  79 -55 -96 -98 -85  14 -71 -98\n
# -53 -34  99  14  74  34  -4  91\n
# -70   2  24  10  49 -10 -75  95\n
# -41  94  59  89  48   2  56  27\n
#  98  33  62 -23  89  78  59  -6\n
# \n
#  -6  59  78  89 -80  31  10  80\n
#  27  56   2  48  78 -16  86 -53\n
#  95 -75 -10  49 -98  -4 -36 -83\n
#  91  -4  34  74 -85  14 -71 -98\n
# -53 -34  99  14 -98 -96 -55  79\n
# -70   2  24  10   0 -31 -84  71\n
# -41  94  59  89 -35 -55  10 -25\n
#  98  33  62 -23 -58 -70   1 -65\n
# \n
# -65   1 -70 -58 -23  62  33  98\n
# -25  10 -55 -35  89  59  94 -41\n
#  71 -84 -31   0  10  24   2 -70\n
#  79 -55 -96 -98  14  99 -34 -53\n
# -98 -71  14 -85  74  34  -4  91\n
# -83 -36  -4 -98  49 -10 -75  95\n
# -53  86 -16  78  48   2  56  27\n
#  80  10  31 -80  89  78  59  -6\n
# '''

# %% [markdown]
# # Exercise 4

# %% [markdown]
# ## Templates

# %%
# %pycat exercise_6_4_template.py
# Out:
# # n is an integer ≥ 1 and black_centre is a Boolean.
# #
# # Prints an n × n square made of alternating concentric
# # layers of black and white squares, with the colour of
# # the central layer determined by black_centre.
# #
# # np.full() is useful.
#
# import numpy as np
#
# # POSSIBLY DEFINE A FUNCTION
#
# def f4(n, black_centre=True):
#     pass
#     # REPLACE THE PASS STATEMENT ABOVE WITH YOUR CODE

# %% [markdown]
# ## Tests

# %%
# %%run_and_test python3 -c "from exercise_6_4 import f4; f4(1)"
#
# '⬛\n'

# %%
# %%run_and_test python3 -c "from exercise_6_4 import f4; f4(1, False)"
#
# '⬜\n'

# %%
# %%run_and_test python3 -c "from exercise_6_4 import f4; f4(2)"
#
# '⬛⬛\n'
# '⬛⬛\n'

# %%
# %%run_and_test python3 -c "from exercise_6_4 import f4; f4(2, False)"
#
# '⬜⬜\n'
# '⬜⬜\n'

# %%
# %%run_and_test python3 -c "from exercise_6_4 import f4; f4(3)"
#
# '⬜⬜⬜\n'
# '⬜⬛⬜\n'
# '⬜⬜⬜\n'

# %%
# %%run_and_test python3 -c "from exercise_6_4 import f4; f4(3, False)"
#
# '⬛⬛⬛\n'
# '⬛⬜⬛\n'
# '⬛⬛⬛\n'

# %%
# %%run_and_test python3 -c "from exercise_6_4 import f4; f4(4)"
#
# '⬜⬜⬜⬜\n'
# '⬜⬛⬛⬜\n'
# '⬜⬛⬛⬜\n'
# '⬜⬜⬜⬜\n'

# %%
# %%run_and_test python3 -c "from exercise_6_4 import f4; f4(4, False)"
#
# '⬛⬛⬛⬛\n'
# '⬛⬜⬜⬛\n'
# '⬛⬜⬜⬛\n'
# '⬛⬛⬛⬛\n'

# %%
# %%run_and_test python3 -c "from exercise_6_4 import f4; f4(5)"
#
# '⬛⬛⬛⬛⬛\n'
# '⬛⬜⬜⬜⬛\n'
# '⬛⬜⬛⬜⬛\n'
# '⬛⬜⬜⬜⬛\n'
# '⬛⬛⬛⬛⬛\n'

# %%
# %%run_and_test python3 -c "from exercise_6_4 import f4; f4(5, False)"
#
# '⬜⬜⬜⬜⬜\n'
# '⬜⬛⬛⬛⬜\n'
# '⬜⬛⬜⬛⬜\n'
# '⬜⬛⬛⬛⬜\n'
# '⬜⬜⬜⬜⬜\n'

# %%
# %%run_and_test python3 -c "from exercise_6_4 import f4; f4(6)"
#
# '⬛⬛⬛⬛⬛⬛\n'
# '⬛⬜⬜⬜⬜⬛\n'
# '⬛⬜⬛⬛⬜⬛\n'
# '⬛⬜⬛⬛⬜⬛\n'
# '⬛⬜⬜⬜⬜⬛\n'
# '⬛⬛⬛⬛⬛⬛\n'

# %%
# %%run_and_test python3 -c "from exercise_6_4 import f4; f4(6, False)"
#
# '⬜⬜⬜⬜⬜⬜\n'
# '⬜⬛⬛⬛⬛⬜\n'
# '⬜⬛⬜⬜⬛⬜\n'
# '⬜⬛⬜⬜⬛⬜\n'
# '⬜⬛⬛⬛⬛⬜\n'
# '⬜⬜⬜⬜⬜⬜\n'

# %%
# %%run_and_test python3 -c "from exercise_6_4 import f4; f4(7)"
#
# '⬜⬜⬜⬜⬜⬜⬜\n'
# '⬜⬛⬛⬛⬛⬛⬜\n'
# '⬜⬛⬜⬜⬜⬛⬜\n'
# '⬜⬛⬜⬛⬜⬛⬜\n'
# '⬜⬛⬜⬜⬜⬛⬜\n'
# '⬜⬛⬛⬛⬛⬛⬜\n'
# '⬜⬜⬜⬜⬜⬜⬜\n'

# %%
# %%run_and_test python3 -c "from exercise_6_4 import f4; f4(7, False)"
#
# '⬛⬛⬛⬛⬛⬛⬛\n'
# '⬛⬜⬜⬜⬜⬜⬛\n'
# '⬛⬜⬛⬛⬛⬜⬛\n'
# '⬛⬜⬛⬜⬛⬜⬛\n'
# '⬛⬜⬛⬛⬛⬜⬛\n'
# '⬛⬜⬜⬜⬜⬜⬛\n'
# '⬛⬛⬛⬛⬛⬛⬛\n'

# %%
# %%run_and_test python3 -c "from exercise_6_4 import f4; f4(8)"
#
# '⬜⬜⬜⬜⬜⬜⬜⬜\n'
# '⬜⬛⬛⬛⬛⬛⬛⬜\n'
# '⬜⬛⬜⬜⬜⬜⬛⬜\n'
# '⬜⬛⬜⬛⬛⬜⬛⬜\n'
# '⬜⬛⬜⬛⬛⬜⬛⬜\n'
# '⬜⬛⬜⬜⬜⬜⬛⬜\n'
# '⬜⬛⬛⬛⬛⬛⬛⬜\n'
# '⬜⬜⬜⬜⬜⬜⬜⬜\n'

# %%
# %%run_and_test python3 -c "from exercise_6_4 import f4; f4(8, False)"
#
# '⬛⬛⬛⬛⬛⬛⬛⬛\n'
# '⬛⬜⬜⬜⬜⬜⬜⬛\n'
# '⬛⬜⬛⬛⬛⬛⬜⬛\n'
# '⬛⬜⬛⬜⬜⬛⬜⬛\n'
# '⬛⬜⬛⬜⬜⬛⬜⬛\n'
# '⬛⬜⬛⬛⬛⬛⬜⬛\n'
# '⬛⬜⬜⬜⬜⬜⬜⬛\n'
# '⬛⬛⬛⬛⬛⬛⬛⬛\n'

# %%
# %%run_and_test python3 -c "from exercise_6_4 import f4; f4(9)"
#
# '⬛⬛⬛⬛⬛⬛⬛⬛⬛\n'
# '⬛⬜⬜⬜⬜⬜⬜⬜⬛\n'
# '⬛⬜⬛⬛⬛⬛⬛⬜⬛\n'
# '⬛⬜⬛⬜⬜⬜⬛⬜⬛\n'
# '⬛⬜⬛⬜⬛⬜⬛⬜⬛\n'
# '⬛⬜⬛⬜⬜⬜⬛⬜⬛\n'
# '⬛⬜⬛⬛⬛⬛⬛⬜⬛\n'
# '⬛⬜⬜⬜⬜⬜⬜⬜⬛\n'
# '⬛⬛⬛⬛⬛⬛⬛⬛⬛\n'

# %%
# %%run_and_test python3 -c "from exercise_6_4 import f4; f4(9, False)"
#
# '⬜⬜⬜⬜⬜⬜⬜⬜⬜\n'
# '⬜⬛⬛⬛⬛⬛⬛⬛⬜\n'
# '⬜⬛⬜⬜⬜⬜⬜⬛⬜\n'
# '⬜⬛⬜⬛⬛⬛⬜⬛⬜\n'
# '⬜⬛⬜⬛⬜⬛⬜⬛⬜\n'
# '⬜⬛⬜⬛⬛⬛⬜⬛⬜\n'
# '⬜⬛⬜⬜⬜⬜⬜⬛⬜\n'
# '⬜⬛⬛⬛⬛⬛⬛⬛⬜\n'
# '⬜⬜⬜⬜⬜⬜⬜⬜⬜\n'

# %% [markdown]
# # Exercise 5

# %% [markdown]
# ## Templates

# %%
# %pycat exercise_6_5_template.py
# Out:
# # L is a list of lists of integers.
# #
# # Prints a rectangle of coloured squares of the same shape as L,
# # with the square at position (i, j) determined by the sign of
# # the sum of all elements in row i and column j, counting the
# # element at (i, j) only once:
# # - blue if the sum is 0,
# # - green if the sum is positive,
# # - red if the sum is negative.
# #
# # The argument L may be modified by the function.
# #
# # For example, the entry -3 corresponds to a blue square
# # in the 3 × 5 rectangle below.
# #
# #   .  .  2  .  .
# #   2  0 -3  7 -4
# #   .  . -4  .  .
# #
# # np.sign() and np.sum() are useful.
# # The axis argument of np.sum() is useful.
#
# import numpy as np
#
# def f5(L):
#     pass
#     # REPLACE THE PASS STATEMENT ABOVE WITH YOUR CODE

# %% [markdown]
# ## Tests

# %%
# %%run_and_test python3 -c "from exercise_6_5 import f5; f5([[]])"
#
# '\n'

# %%
# %%run_and_test python3 -c "from exercise_6_5 import f5; f5([[0]])"
#
# '🟦\n'

# %%
# %%run_and_test python3 -c "from exercise_6_5 import f5; f5([[2]])"
#
# '🟩\n'

# %%
# %%run_and_test python3 -c "from exercise_6_5 import f5; f5([[-2]])"
#
# '🟥\n'

# %%
statements = 'from exercise_6_5 import f5; '\
             'f5([[4, -6, -5], [6, -7, 6]])'

# %%
# %%run_and_test python3 -c "$statements"
#
# '🟥🟥🟥\n'
# '🟩🟥🟦\n'

# %%
statements = 'from exercise_6_5 import f5; '\
             'f5([[7, -2], [6, -8], [-9, -4]])'

# %%
# %%run_and_test python3 -c "$statements"
#
# '🟩🟥\n'
# '🟥🟥\n'
# '🟦🟥\n'

# %%
statements = 'from exercise_6_5 import f5; '\
             'f5([[8, 18, 14], [1, -19, -19], [15, 19, -4]])'

# %%
# %%run_and_test python3 -c "$statements"
#
# '🟩🟩🟩\n'
# '🟥🟦🟥\n'
# '🟩🟩🟩\n'

# %%
statements = 'from exercise_6_5 import f5; '\
             'L = [[2, 9, 16, 6, -28], [29, 22, 20, -28, -30],'\
             '     [27, -26, 20, -16, 27]]; f5(L)'

# %%
# %%run_and_test python3 -c "$statements"
#
# '🟩🟩🟩🟥🟩\n'
# '🟩🟥🟩🟩🟩\n'
# '🟩🟩🟩🟩🟥\n'

# %%
statements = 'from exercise_6_5 import f5; '\
             'L = [[19, -24, 13], [-26, -2, -3], [2, -10, -7],'\
             '     [12, 22, -7], [-3, -23, 26]]; f5(L)'

# %%
# %%run_and_test python3 -c "$statements"
#
# '🟥🟥🟩\n'
# '🟥🟥🟥\n'
# '🟥🟥🟩\n'
# '🟩🟥🟩\n'
# '🟩🟥🟥\n'

# %%
statements = 'from exercise_6_5 import f5; '\
             'L = [[24, 40, 18, -37, 22, 11, -31],'\
             '     [-2, -33, -12, 13, -4, 10, -35],'\
             '     [-11, -16, 18, -6, 31, 18, 40],'\
             '     [-37, 39, -14, -33, -25, -16, 22]]; f5(L)'

# %%
# %%run_and_test python3 -c "$statements"
#
# '🟥🟩🟩🟩🟩🟩🟩\n'
# '🟥🟦🟥🟥🟥🟥🟥\n'
# '🟩🟩🟩🟩🟩🟩🟩\n'
# '🟥🟥🟥🟥🟥🟥🟥\n'

# %%
statements = 'from exercise_6_5 import f5; '\
             'L = [[-22, -4, 26, -25], [-26, 13, 27, 4], [-11, -14, -24, 34],'\
             '     [11, -32, 36, 9], [11, 9, -23, -35], [16, 25, 18, 0],'\
             '     [10, 39, -21, 8]]; f5(L)'

# %%
# %%run_and_test python3 -c "$statements"
#
# '🟥🟩🟥🟥\n'
# '🟩🟩🟩🟩\n'
# '🟥🟩🟩🟥\n'
# '🟩🟩🟩🟩\n'
# '🟥🟥🟩🟥\n'
# '🟩🟩🟩🟩\n'
# '🟩🟩🟩🟩\n'

# %%
statements = 'from exercise_6_5 import f5; '\
             'L = [[-6, -32, 48, -29, -30, -26, -49, 10],'\
             '     [-43, -26, 37, 16, -25, 14, 33, -39],'\
             '     [22, 6, 49, 49, -25, -37, -2, -21],'\
             '     [11, 6, 15, -35, 24, 33, -14, 14],'\
             '     [-47, 22, 14, 44, 50, -23, -4, -14],'\
             '     [-42, -13, -46, 24, -18, -11, -41, -46],'\
             '     [27, -7, 19, 33, 49, -4, 49, -36],'\
             '     [35, -43, -27, -29, 48, 46, 29, 40]]; f5(L)'

# %%
# %%run_and_test python3 -c "$statements"
#
# '🟥🟥🟥🟥🟥🟥🟥🟥\n'
# '🟥🟥🟩🟩🟩🟥🟥🟥\n'
# '🟥🟥🟩🟩🟩🟩🟩🟥\n'
# '🟦🟥🟩🟩🟩🟩🟩🟥\n'
# '🟩🟥🟩🟩🟩🟩🟩🟥\n'
# '🟥🟥🟥🟥🟥🟥🟥🟥\n'
# '🟩🟩🟩🟩🟩🟩🟩🟩\n'
# '🟩🟩🟩🟩🟩🟩🟩🟥\n'

# %% [markdown]
# # Exercise 6

# %% [markdown]
# ## Templates

# %%
# %pycat exercise_6_6_template.py
# Out:
# # L is a nonempty list of lists of integers forming a square.
# #
# # Prints a square of coloured squares of the same shape as L,
# # with the square at position (i, j) determined by the sign of
# # the sum of all elements in row i and column j, counting the
# # element at (i, j) only once:
# # - blue if the sum is 0,
# # - green if the sum is positive,
# # - red if the sum is negative.
# #
# # For example, the entry -3 corresponds to a green square
# # in the 3 × 3 square below.
# #
# #   .  2  .
# #   0 -3  7
# #   . -4  .
# #
# #
# # np.sign(), np.sum(), and np.newaxis are useful.
# # The axis argument of np.sum() is useful.
#
# import numpy as np
#
# def f6(L):
#     pass
#     # REPLACE THE PASS STATEMENT ABOVE WITH YOUR CODE

# %% [markdown]
# ## Tests

# %%
# %%run_and_test python3 -c "from exercise_6_6 import f6; f6([[0]])"
#
# '🟦\n'

# %%
# %%run_and_test python3 -c "from exercise_6_6 import f6; f6([[2]])"
#
# '🟩\n'

# %%
# %%run_and_test python3 -c "from exercise_6_6 import f6; f6([[-2]])"
#
# '🟥\n'

# %%
statements = 'from exercise_6_6 import f6; '\
             'f6([[4, -12], [8, -3]])'

# %%
# %%run_and_test python3 -c "$statements"
#
# '🟦🟥\n'
# '🟩🟥\n'

# %%
statements = 'from exercise_6_6 import f6; '\
             'f6([[0, 8, 7], [4, 6, -6], [-2, -7, -5]])'

# %%
# %%run_and_test python3 -c "$statements"
#
# '🟩🟩🟩\n'
# '🟩🟩🟩\n'
# '🟥🟦🟥\n'

# %%
statements = 'from exercise_6_6 import f6; '\
             'L = [[17, 4, 18, 18], [5, 9, -12, 0], [17, 13, -14, -13],'\
             '     [7, -16, 15, -14]]; f6(L)'

# %%
# %%run_and_test python3 -c "$statements"
#
# '🟩🟩🟩🟩\n'
# '🟩🟩🟩🟥\n'
# '🟩🟦🟩🟩\n'
# '🟩🟩🟥🟥\n'

# %%
statements = 'from exercise_6_6 import f6; '\
             'L = [[13, -26, 8, -26, 7], [12, -3, 20, 4, 14],'\
             '      [-1, -3, 16, -4, -10], [4, 22, -26, 1, -19],'\
             '      [-4, -20, -7, -20, -10]]; f6(L)'

# %%
# %%run_and_test python3 -c "$statements"
#
# '🟥🟥🟥🟥🟥\n'
# '🟩🟩🟩🟥🟩\n'
# '🟩🟥🟥🟥🟥\n'
# '🟩🟥🟩🟥🟥\n'
# '🟥🟥🟥🟥🟥\n'

# %%
statements = 'from exercise_6_6 import f6; '\
             'L = [[7, -22, -37, 32, 34, 38], [-13, -30, -13, -9, 10, 4],'\
             '      [-33, -32, -6, 33, 3, 12], [25, 11, -7, 18, -27, 8],'\
             '      [33, 21, -4, 27, -15, 7], [19, -23, 0, -17, 4, -28]]; '\
             'f6(L)'

# %%
# %%run_and_test python3 -c "$statements"
#
# '🟩🟥🟩🟩🟩🟩\n'
# '🟦🟥🟥🟩🟥🟥\n'
# '🟩🟥🟥🟩🟥🟩\n'
# '🟩🟥🟥🟩🟩🟩\n'
# '🟩🟥🟩🟩🟩🟩\n'
# '🟥🟥🟥🟩🟥🟩\n'

# %%
statements = 'from exercise_6_6 import f6; '\
             'L = [[-25, 40, 15, 35, -22, -49, 45],'\
             '     [-27, 35, -30, 4, -8, -41, -32],'\
             '     [-14, -14, 20, -5, -24, -45, 36],'\
             '     [39, -45, 13, -42, 9, -29, 13],'\
             '     [-9, -5, 44, -45, -20, -6, -42],'\
             '     [33, -10, 17, -23, -32, 4, -4],'\
             '     [-46, -16, -36, -30, -39, -3, -10]]; f6(L)'

# %%
# %%run_and_test python3 -c "$statements"
#
# '🟩🟥🟩🟥🟥🟥🟦\n'
# '🟥🟥🟥🟥🟥🟥🟥\n'
# '🟥🟥🟥🟥🟥🟥🟥\n'
# '🟥🟥🟥🟥🟥🟥🟥\n'
# '🟥🟥🟥🟥🟥🟥🟥\n'
# '🟥🟥🟩🟥🟥🟥🟥\n'
# '🟥🟥🟥🟥🟥🟥🟥\n'

# %%
statements = 'from exercise_6_6 import f6; '\
             'L = [[-6, -32, 48, -29, -30, -26, -49, 10],'\
             '     [-43, -26, 37, 16, -25, 14, 33, -39],'\
             '     [22, 6, 49, 49, -25, -37, -2, -21],'\
             '     [11, 6, 15, -35, 24, 33, -14, 14],'\
             '     [-47, 22, 14, 44, 50, -23, -4, -14],'\
             '     [-42, -13, -46, 24, -18, -11, -41, -46],'\
             '     [27, -7, 19, 33, 49, -4, 49, -36],'\
             '     [35, -43, -27, -29, 48, 46, 29, 40]]; f6(L)'

# %%
# %%run_and_test python3 -c "$statements"
#
# '🟥🟥🟥🟥🟥🟥🟥🟥\n'
# '🟥🟥🟩🟩🟩🟥🟥🟥\n'
# '🟥🟥🟩🟩🟩🟩🟩🟥\n'
# '🟦🟥🟩🟩🟩🟩🟩🟥\n'
# '🟩🟥🟩🟩🟩🟩🟩🟥\n'
# '🟥🟥🟥🟥🟥🟥🟥🟥\n'
# '🟩🟩🟩🟩🟩🟩🟩🟩\n'
# '🟩🟩🟩🟩🟩🟩🟩🟥\n'
