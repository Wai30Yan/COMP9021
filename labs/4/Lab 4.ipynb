# %%
load_ext run_and_test

# %% [markdown]
# # Exercise 1

# %% [markdown]
# ## Templates

# %%
# %pycat exercise_4_1_template.py
# Out:
# # n is an integer ≥ 1.
# #
# # For each integer i from n down to 1,
# # print the sequence obtained by repeatedly dividing i by 2
# # and taking the floor of the result at each step.
# #
# # The sequence starts with i and stops before the value would become 0.
# #
# # Each integer is printed in a field
# # whose width is equal to the number of digits of n plus 1.
# # Each sequence is printed on its own line.
# #
# # The output is printed, not returned.
#
# def f1(n):
#     pass
#     # REPLACE THE PASS STATEMENT ABOVE WITH YOUR CODE

# %% [markdown]
# ## Tests

# %%
# %%run_and_test python3 -c "from exercise_4_1 import f1; f1(1)"
#
# ' 1\n'
# Out:
# PASSED
#
#    1

# %%
# %%run_and_test python3 -c "from exercise_4_1 import f1; f1(2)"
#
# '''
#  2 1\n
#  1\n
# '''
# Out:
# PASSED
#
#    2 1
#    1

# %%
# %%run_and_test python3 -c "from exercise_4_1 import f1; f1(8)"
#
# '''
#  8 4 2 1\n
#  7 3 1\n
#  6 3 1\n
#  5 2 1\n
#  4 2 1\n
#  3 1\n
#  2 1\n
#  1\n
# '''
# Out:
# PASSED
#
#    8 4 2 1
#    7 3 1
#    6 3 1
#    5 2 1
#    4 2 1
#    3 1
#    2 1
#    1

# %%
# %%run_and_test python3 -c "from exercise_4_1 import f1; f1(13)"
#
# '''
#  13  6  3  1\n
#  12  6  3  1\n
#  11  5  2  1\n
#  10  5  2  1\n
#   9  4  2  1\n
#   8  4  2  1\n
#   7  3  1\n
#   6  3  1\n
#   5  2  1\n
#   4  2  1\n
#   3  1\n
#   2  1\n
#   1\n
# '''
# Out:
# FAILED
#
# - 13 6 3 1
# +  13  6  3  1
# ? +   + +   +
# - 12 6 3 1
# +  12  6  3  1
# ? +   + +   +
# - 11 5 2 1
# +  11  5  2  1
# ? +   + +   +
# - 10 5 2 1
# +  10  5  2  1
# ? +   + +   +
# -  9 4 2 1
# +   9  4  2  1
# ? +   + +   +
# -  8 4 2 1
# +   8  4  2  1
# ? +   + +   +
# -  7 3 1
# +   7  3  1
# ? +   + +
# -  6 3 1
# +   6  3  1
# ? +   + +
# -  5 2 1
# +   5  2  1
# ? +   + +
# -  4 2 1
# +   4  2  1
# ? +   + +
# -  3 1
# +   3  1
# ? +   +
# -  2 1
# +   2  1
# ? +   +
# -  1
# +   1
# ? +

# %%
# %%run_and_test python3 -c "from exercise_4_1 import f1; f1(26)"
#
# '''
#  26 13  6  3  1\n
#  25 12  6  3  1\n
#  24 12  6  3  1\n
#  23 11  5  2  1\n
#  22 11  5  2  1\n
#  21 10  5  2  1\n
#  20 10  5  2  1\n
#  19  9  4  2  1\n
#  18  9  4  2  1\n
#  17  8  4  2  1\n
#  16  8  4  2  1\n
#  15  7  3  1\n
#  14  7  3  1\n
#  13  6  3  1\n
#  12  6  3  1\n
#  11  5  2  1\n
#  10  5  2  1\n
#   9  4  2  1\n
#   8  4  2  1\n
#   7  3  1\n
#   6  3  1\n
#   5  2  1\n
#   4  2  1\n
#   3  1\n
#   2  1\n
#   1\n
# '''

# %%
# %%run_and_test -s 2500 python3 -c "from exercise_4_1 import f1; f1(100)"
#
# '''
#  100  50  25  12   6   3   1\n
#   99  49  24  12   6   3   1\n
#   98  49  24  12   6   3   1\n
#   97  48  24  12   6   3   1\n
#   96  48  24  12   6   3   1\n
#   95  47  23  11   5   2   1\n
#   94  47  23  11   5   2   1\n
#   93  46  23  11   5   2   1\n
#   92  46  23  11   5   2   1\n
#   91  45  22  11   5   2   1\n
#   90  45  22  11   5   2   1\n
#   89  44  22  11   5   2   1\n
#   88  44  22  11   5   2   1\n
#   87  43  21  10   5   2   1\n
#   86  43  21  10   5   2   1\n
#   85  42  21  10   5   2   1\n
#   84  42  21  10   5   2   1\n
#   83  41  20  10   5   2   1\n
#   82  41  20  10   5   2   1\n
#   81  40  20  10   5   2   1\n
#   80  40  20  10   5   2   1\n
#   79  39  19   9   4   2   1\n
#   78  39  19   9   4   2   1\n
#   77  38  19   9   4   2   1\n
#   76  38  19   9   4   2   1\n
#   75  37  18   9   4   2   1\n
#   74  37  18   9   4   2   1\n
#   73  36  18   9   4   2   1\n
#   72  36  18   9   4   2   1\n
#   71  35  17   8   4   2   1\n
#   70  35  17   8   4   2   1\n
#   69  34  17   8   4   2   1\n
#   68  34  17   8   4   2   1\n
#   67  33  16   8   4   2   1\n
#   66  33  16   8   4   2   1\n
#   65  32  16   8   4   2   1\n
#   64  32  16   8   4   2   1\n
#   63  31  15   7   3   1\n
#   62  31  15   7   3   1\n
#   61  30  15   7   3   1\n
#   60  30  15   7   3   1\n
#   59  29  14   7   3   1\n
#   58  29  14   7   3   1\n
#   57  28  14   7   3   1\n
#   56  28  14   7   3   1\n
#   55  27  13   6   3   1\n
#   54  27  13   6   3   1\n
#   53  26  13   6   3   1\n
#   52  26  13   6   3   1\n
#   51  25  12   6   3   1\n
#   50  25  12   6   3   1\n
#   49  24  12   6   3   1\n
#   48  24  12   6   3   1\n
#   47  23  11   5   2   1\n
#   46  23  11   5   2   1\n
#   45  22  11   5   2   1\n
#   44  22  11   5   2   1\n
#   43  21  10   5   2   1\n
#   42  21  10   5   2   1\n
#   41  20  10   5   2   1\n
#   40  20  10   5   2   1\n
#   39  19   9   4   2   1\n
#   38  19   9   4   2   1\n
#   37  18   9   4   2   1\n
#   36  18   9   4   2   1\n
#   35  17   8   4   2   1\n
#   34  17   8   4   2   1\n
#   33  16   8   4   2   1\n
#   32  16   8   4   2   1\n
#   31  15   7   3   1\n
#   30  15   7   3   1\n
#   29  14   7   3   1\n
#   28  14   7   3   1\n
#   27  13   6   3   1\n
#   26  13   6   3   1\n
#   25  12   6   3   1\n
#   24  12   6   3   1\n
#   23  11   5   2   1\n
#   22  11   5   2   1\n
#   21  10   5   2   1\n
#   20  10   5   2   1\n
#   19   9   4   2   1\n
#   18   9   4   2   1\n
#   17   8   4   2   1\n
#   16   8   4   2   1\n
#   15   7   3   1\n
#   14   7   3   1\n
#   13   6   3   1\n
#   12   6   3   1\n
#   11   5   2   1\n
#   10   5   2   1\n
#    9   4   2   1\n
#    8   4   2   1\n
#    7   3   1\n
#    6   3   1\n
#    5   2   1\n
#    4   2   1\n
#    3   1\n
#    2   1\n
#    1\n
# '''

# %%
# %%run_and_test -r :600 python3 -c "from exercise_4_1 import f1; f1(100_000)"
#
# '''
#  100000  50000  25000  12500   6250   3125   1562    781    390    195     97     48     24     12      6      3      1\n
#   99999  49999  24999  12499   6249   3124   1562    781    390    195     97     48     24     12      6      3      1\n
#   99998  49999  24999  12499   6249   3124   1562    781    390    195     97     48     24     12      6      3      1\n
#   99997  49998  24999  12499   6249   3124   1562    781    390    195     97     48     24     12      6      3      1\n
#   99996  49998  24999  12499   6249   3124   1562    781    390    195     97     48     24     12      6      3      1\n
# '''

# %% [markdown]
# # Exercise 2

# %% [markdown]
# ## Templates

# %%
# %pycat exercise_4_2_template.py
# Out:
# # S is a nonempty set of integers.
# #
# # Returns a list of sets consisting of all subsets of S
# # obtained by repeatedly removing the largest elements of S,
# # starting with S itself and ending with the set
# # containing only the smallest element of S.
# #
# # The sets appear in decreasing order of size.
# #
# # The argument S must not be modified by the function.
#
# def f2(S):
#     return []
#     # REPLACE THE RETURN STATEMENT ABOVE WITH YOUR CODE

# %% [markdown]
# ## Tests

# %%
statements = 'from exercise_4_2 import f2; S = {1}; U = f2(S); '\
             'print("S unchanged:", S == {1}); '\
             'print("U is a list:", isinstance(U, list)); '\
             'print("All elements of U are sets:", all(isinstance(x, set) for x in U)); '\
             'print("The sets in U:", [sorted(x) for x in U])'

# %%
# %%run_and_test python3 -c "$statements"
#
# 'S unchanged: True\n'
# 'U is a list: True\n'
# 'All elements of U are sets: True\n'
# 'The sets in U: [[1]]\n'
# Out:
# PASSED
#
#   S unchanged: True
#   U is a list: True
#   All elements of U are sets: True
#   The sets in U: [[1]]

# %%
statements = 'from exercise_4_2 import f2; S = {1, 2}; U = f2(S); '\
             'print("S unchanged:", S == {1, 2}); '\
             'print("U is a list:", isinstance(U, list)); '\
             'print("All elements of U are sets:", all(isinstance(x, set) for x in U)); '\
             'print("The sets in U:", [sorted(x) for x in U])'

# %%
# %%run_and_test python3 -c "$statements"
#
# 'S unchanged: True\n'
# 'U is a list: True\n'
# 'All elements of U are sets: True\n'
# 'The sets in U: [[1, 2], [1]]\n'
# Out:
# PASSED
#
#   S unchanged: True
#   U is a list: True
#   All elements of U are sets: True
#   The sets in U: [[1, 2], [1]]

# %%
statements = 'from exercise_4_2 import f2; S = {1, 2, 3, 4}; U = f2(S); '\
             'print("S unchanged:", S == {1, 2, 3, 4}); '\
             'print("U is a list:", isinstance(U, list)); '\
             'print("All elements of U are sets:", all(isinstance(x, set) for x in U)); '\
             'print("The sets in U:", [sorted(x) for x in U])'

# %%
# %%run_and_test python3 -c "$statements"
#
# 'S unchanged: True\n'
# 'U is a list: True\n'
# 'All elements of U are sets: True\n'
# 'The sets in U: [[1, 2, 3, 4], [1, 2, 3], [1, 2], [1]]\n'
# Out:
# PASSED
#
#   S unchanged: True
#   U is a list: True
#   All elements of U are sets: True
#   The sets in U: [[1, 2, 3, 4], [1, 2, 3], [1, 2], [1]]

# %%
statements = 'from exercise_4_2 import f2; '\
             'S = {3, 67, -59, 8, 81, -14, -42, 29}; U = f2(S); '\
             'print("S unchanged:", S == {3, 67, -59, 8, 81, -14, -42, 29}); '\
             'print("U is a list:", isinstance(U, list)); '\
             'print("All elements of U are sets:", all(isinstance(x, set) for x in U)); '\
             'print("The sets in U:", [sorted(x) for x in U])'

# %%
# %%run_and_test python3 -c "$statements"
#
# 'S unchanged: True\n'
# 'U is a list: True\n'
# 'All elements of U are sets: True\n'
# 'The sets in U: '
# '[[-59, -42, -14, 3, 8, 29, 67, 81], '
#  '[-59, -42, -14, 3, 8, 29, 67], '
#  '[-59, -42, -14, 3, 8, 29], '
#  '[-59, -42, -14, 3, 8], '
#  '[-59, -42, -14, 3], '
#  '[-59, -42, -14], '
#  '[-59, -42], '
#  '[-59]]\n'
# Out:
# PASSED
#
#   S unchanged: True
#   U is a list: True
#   All elements of U are sets: True
#   The sets in U: [[-59, -42, -14, 3, 8, 29, 67, 81], [-59, -42, -14, 3, 8, 29, 67], [-59, -42, -14, 3, 8, 29], [-59, -42, -14, 3, 8], [-59, -42, -14, 3], [-59, -42, -14], [-59, -42], [-59]]

# %%
statements = 'from exercise_4_2 import f2; '\
             'S = {-891, 358, -985, 104, 551, -630, 203, -921, -344, 298, -665, -843, -138}; U = f2(S); '\
             'print("S unchanged:", S == {-891, 358, -985, 104, 551, -630, 203, -921, -344, 298, -665, -843, -138}); '\
             'print("U is a list:", isinstance(U, list)); '\
             'print("All elements of U are sets:", all(isinstance(x, set) for x in U)); '\
             'print("The sets in U:", [sorted(x) for x in U])'

# %%
# %%run_and_test python3 -c "$statements"
#
# 'S unchanged: True\n'
# 'U is a list: True\n'
# 'All elements of U are sets: True\n'
# 'The sets in U: '
# '[[-985, -921, -891, -843, -665, -630, -344, -138, 104, 203, 298, 358, 551], '
#  '[-985, -921, -891, -843, -665, -630, -344, -138, 104, 203, 298, 358], '
#  '[-985, -921, -891, -843, -665, -630, -344, -138, 104, 203, 298], '
#  '[-985, -921, -891, -843, -665, -630, -344, -138, 104, 203], '
#  '[-985, -921, -891, -843, -665, -630, -344, -138, 104], '
#  '[-985, -921, -891, -843, -665, -630, -344, -138], '
#  '[-985, -921, -891, -843, -665, -630, -344], '
#  '[-985, -921, -891, -843, -665, -630], '
#  '[-985, -921, -891, -843, -665], '
#  '[-985, -921, -891, -843], '
#  '[-985, -921, -891], '
#  '[-985, -921], '
#  '[-985]]\n'
# Out:
# PASSED
#
#   S unchanged: True
#   U is a list: True
#   All elements of U are sets: True
#   The sets in U: [[-985, -921, -891, -843, -665, -630, -344, -138, 104, 203, 298, 358, 551], [-985, -921, -891, -843, -665, -630, -344, -138, 104, 203, 298, 358], [-985, -921, -891, -843, -665, -630, -344, -138, 104, 203, 298], [-985, -921, -891, -843, -665, -630, -344, -138, 104, 203], [-985, -921, -891, -843, -665, -630, -344, -138, 104], [-985, -921, -891, -843, -665, -630, -344, -138], [-985, -921, -891, -843, -665, -630, -344], [-985, -921, -891, -843, -665, -630], [-985, -921, -891, -843, -665], [-985, -921, -891, -843], [-985, -921, -891], [-985, -921], [-985]]

# %% [markdown]
# # Question 3

# %% [markdown]
# ## Templates

# %%
# %pycat exercise_4_3_template.py
# Out:
# # L is an increasing list of integers.
# #
# # As long as there exists an element of L
# # that is neither the first nor the last element
# # and is equal to the average of its two neighbors,
# # removes the leftmost such element.
# #
# # Returns L after all such removals have been performed.
#
# def f3(L):
#     # INSERT YOUR CODE HERE
#     return L

# %% [markdown]
# ## Tests

# %%
# %%run_and_test python3 -c "from exercise_4_3 import f3; print(f3([1]))"
#
# '[1]\n'
# Out:
# PASSED
#
#   [1]

# %%
# %%run_and_test python3 -c "from exercise_4_3 import f3; print(f3([1, 2]))"
#
# '[1, 2]\n'
# Out:
# PASSED
#
#   [1, 2]

# %%
# %%run_and_test python3 -c "from exercise_4_3 import f3; print(f3([1, 2, 3]))"
#
# '[1, 3]\n'
# Out:
# PASSED
#
#   [1, 3]

# %%
# %%run_and_test python3 -c "from exercise_4_3 import f3; print(f3([1, 1, 2]))"
#
# '[1, 1, 2]\n'
# Out:
# PASSED
#
#   [1, 1, 2]

# %%
# %%run_and_test python3 -c "from exercise_4_3 import f3; print(f3([1] * 100))"
#
# '[1, 1]\n'
# Out:
# PASSED
#
#   [1, 1]

# %%
# %%run_and_test python3 -c "from exercise_4_3 import f3; print(f3([1] * 10 + [2] * 10 + [3] * 10))"
#
# '[1, 1, 2, 2, 3, 3]\n'
# Out:
# PASSED
#
#   [1, 1, 2, 2, 3, 3]

# %%
# %%run_and_test python3 -c "from exercise_4_3 import f3; print(f3([1, 2, 3, 5, 9, 17, 33]))"
#
# '[1, 33]\n'
# Out:
# PASSED
#
#   [1, 33]

# %%
# %%run_and_test python3 -c "from exercise_4_3 import f3; print(f3([5, 10, 15, 25, 30, 40, 50, 70, 72, 75, 78]))"
#
# '[5, 25, 30, 70, 72, 78]\n'
# Out:
# PASSED
#
#   [5, 25, 30, 70, 72, 78]

# %% [markdown]
# # Question 4

# %% [markdown]
# ## Templates

# %%
# %pycat exercise_4_4_template.py
# Out:
# # n is an integer.
# #
# # Prints an equality expressing n as a sum of distinct powers of 2.
# # If n is negative, the equality expresses n as the negative of such a sum.
# # For n = 0, the output is "0 = 0".
#
# # The output is printed out, not returned.
#
# def f4(n):
#     pass
#     #REPLACE THE PASS STATEMENT ABOVE WITH YOUR CODE

# %% [markdown]
# ## Tests

# %%
# %%run_and_test python3 -c "from exercise_4_4 import f4; f4(0)"
#
# '0 = 0\n'
# Out:
# PASSED
#
#   0 = 0

# %%
# %%run_and_test python3 -c "from exercise_4_4 import f4; f4(1)"
#
# '1 = 2^0\n'
# Out:
# PASSED
#
#   1 = 2^0

# %%
# %%run_and_test python3 -c "from exercise_4_4 import f4; f4(-1)"
#
# '-1 = -2^0\n'
# Out:
# PASSED
#
#   -1 = -2^0

# %%
# %%run_and_test python3 -c "from exercise_4_4 import f4; f4(2)"
#
# '2 = 2^1\n'
# Out:
# PASSED
#
#   2 = 2^1

# %%
# %%run_and_test python3 -c "from exercise_4_4 import f4; f4(-2)"
#
# '-2 = -2^1\n'
# Out:
# PASSED
#
#   -2 = -2^1

# %%
# %%run_and_test python3 -c "from exercise_4_4 import f4; f4(3)"
#
# '3 = 2^1 + 2^0\n'
# Out:
# PASSED
#
#   3 = 2^1 + 2^0

# %%
# %%run_and_test python3 -c "from exercise_4_4 import f4; f4(-3)"
#
# '-3 = -2^1 - 2^0\n'
# Out:
# PASSED
#
#   -3 = -2^1 - 2^0

# %%
# %%run_and_test python3 -c "from exercise_4_4 import f4; f4(7)"
#
# '7 = 2^2 + 2^1 + 2^0\n'
# Out:
# PASSED
#
#   7 = 2^2 + 2^1 + 2^0

# %%
# %%run_and_test python3 -c "from exercise_4_4 import f4; f4(-7)"
#
# '-7 = -2^2 - 2^1 - 2^0\n'
# Out:
# PASSED
#
#   -7 = -2^2 - 2^1 - 2^0

# %%
# %%run_and_test python3 -c "from exercise_4_4 import f4; f4(19)"
#
# '19 = 2^4 + 2^1 + 2^0\n'
# Out:
# PASSED
#
#   19 = 2^4 + 2^1 + 2^0

# %%
# %%run_and_test python3 -c "from exercise_4_4 import f4; f4(-19)"
#
# '-19 = -2^4 - 2^1 - 2^0\n'
# Out:
# PASSED
#
#   -19 = -2^4 - 2^1 - 2^0

# %%
# %%run_and_test python3 -c "from exercise_4_4 import f4; f4(1234567890)"
#
# '1234567890 = 2^30 + 2^27 + 2^24 + 2^23 + 2^20 + 2^18 + 2^17 + 2^9 + 2^7 + 2^6 + 2^4 + 2^1\n'
# Out:
# PASSED
#
#   1234567890 = 2^30 + 2^27 + 2^24 + 2^23 + 2^20 + 2^18 + 2^17 + 2^9 + 2^7 + 2^6 + 2^4 + 2^1

# %%
# %%run_and_test python3 -c "from exercise_4_4 import f4; f4(-9876543210)"
#
# '-9876543210 = -2^33 - 2^30 - 2^27 - 2^26 - 2^23 - 2^21 - 2^20 - 2^12 - 2^10 - 2^9 - 2^7 - 2^6 - 2^5 - 2^3 - 2^1\n'
# Out:
# PASSED
#
#   -9876543210 = -2^33 - 2^30 - 2^27 - 2^26 - 2^23 - 2^21 - 2^20 - 2^12 - 2^10 - 2^9 - 2^7 - 2^6 - 2^5 - 2^3 - 2^1

# %% [markdown]
# # Question 5

# %% [markdown]
# ## Templates

# %%
# %pycat exercise_4_5_template.py
# Out:
# # All arguments, if any, are integers.
# #
# # Returns a list whose i-th element is a pair consisting of
# # (L[i], L[-i-1]) and (L[-i-1], L[i]),
# # where L is the sequence of arguments.
#
# def f5(*L):
#     return []
#     # REPLACE THE RETURN STATEMENT ABOVE WITH YOUR CODE

# %% [markdown]
# ## Tests

# %%
# %%run_and_test python3 -c "from exercise_4_5 import f5; print(f5())"
#
# '[]\n'

# %%
# %%run_and_test python3 -c "from exercise_4_5 import f5; print(f5(0))"
#
# '[((0, 0), (0, 0))]\n'

# %%
# %%run_and_test python3 -c "from exercise_4_5 import f5; print(f5(0, 1))"
#
# '[((0, 1), (1, 0)), ((1, 0), (0, 1))]\n'

# %%
# %%run_and_test python3 -c "from exercise_4_5 import f5; print(f5(0, 1, 2))"
#
# '[((0, 2), (2, 0)), ((1, 1), (1, 1)), ((2, 0), (0, 2))]\n'

# %%
# %%run_and_test python3 -c "from exercise_4_5 import f5; print(f5(*range(8)))"
#
# '[((0, 7), (7, 0)), '
#  '((1, 6), (6, 1)), '
#  '((2, 5), (5, 2)), '
#  '((3, 4), (4, 3)), '
#  '((4, 3), (3, 4)), '
#  '((5, 2), (2, 5)), '
#  '((6, 1), (1, 6)), '
#  '((7, 0), (0, 7))]\n'

# %%
# %%run_and_test python3 -c "from exercise_4_5 import f5; print(f5(60, 28, 56, 8, 55, 98, 60, 73, 19, 21, 62, 27, 22))"
#
# '[((60, 22), (22, 60)), '
#  '((28, 27), (27, 28)), '
#  '((56, 62), (62, 56)), '
#  '((8, 21), (21, 8)), '
#  '((55, 19), (19, 55)), '
#  '((98, 73), (73, 98)), '
#  '((60, 60), (60, 60)), '
#  '((73, 98), (98, 73)), '
#  '((19, 55), (55, 19)), '
#  '((21, 8), (8, 21)), '
#  '((62, 56), (56, 62)), '
#  '((27, 28), (28, 27)), '
#  '((22, 60), (60, 22))]\n'

# %% [markdown]
# # Exercise 6

# %% [markdown]
# ## Templates

# %%
# %pycat exercise_4_6_template.py
# Out:
# # All arguments, if any, are integers.
# #
# # Let L be the sequence of arguments.
# # Returns the list consisting of:
# # - the tuple formed by the elements of L followed by them in reverse order;
# # - the tuple formed by the elements of L in reverse order followed by them
# #   in their original order.
#
# def f6(*L):
#     return []
#     # REPLACE THE RETURN STATEMENT ABOVE WITH YOUR CODE

# %% [markdown]
# ## Tests

# %%
# %%run_and_test python3 -c "from exercise_4_6 import f6; print(f6())"
#
# '[]\n'

# %%
# %%run_and_test python3 -c "from exercise_4_6 import f6; print(f6(0))"
#
# '[(0, 0), (0, 0)]\n'

# %%
# %%run_and_test python3 -c "from exercise_4_6 import f6; print(f6(0, 1))"
#
# '[(0, 1, 1, 0), (1, 0, 0, 1)]\n'

# %%
# %%run_and_test python3 -c "from exercise_4_6 import f6; print(f6(0, 1, 2))"
#
# '[(0, 1, 2, 2, 1, 0), (2, 1, 0, 0, 1, 2)]\n'

# %%
# %%run_and_test python3 -c "from exercise_4_6 import f6; print(f6(*range(8)))"
#
# '[(0, 1, 2, 3, 4, 5, 6, 7, 7, 6, 5, 4, 3, 2, 1, 0), '
#   '(7, 6, 5, 4, 3, 2, 1, 0, 0, 1, 2, 3, 4, 5, 6, 7)]\n'

# %%
# %%run_and_test python3 -c "from exercise_4_6 import f6; print(f6(60, 28, 56, 8, 55, 98, 60, 73, 19, 21, 62, 27, 22))"
#
# '[(60, 28, 56, 8, 55, 98, 60, 73, 19, 21, 62, 27, 22, 22, 27, 62, 21, 19, 73, 60, 98, 55, 8, 56, 28, 60), '
#  '(22, 27, 62, 21, 19, 73, 60, 98, 55, 8, 56, 28, 60, 60, 28, 56, 8, 55, 98, 60, 73, 19, 21, 62, 27, 22)]\n'
